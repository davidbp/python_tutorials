# %%
import skopt
from skopt import Optimizer
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#?skopt.space.Categorical

# %%
def f(x, noise_level=0.05, random_state=123):
    #np.random.seed(random_state)
    return np.sin(5 * x[0]) * (1 - np.tanh(x[0] ** 2)) + np.random.randn() * noise_level

# %%
noise_level = 0.05

x = np.linspace(-2, 2, 400).reshape(-1, 1)

fx = [f(x_i, noise_level=noise_level) for x_i in x]
plt.plot(x, fx, "r--", label="True (unknown)")

plt.fill(np.concatenate([x, x[::-1]]),
         np.concatenate(([fx_i - 1.9600 * noise_level for fx_i in fx], 
                         [fx_i + 1.9600 * noise_level for fx_i in fx[::-1]])),
         alpha=.2, fc="r", ec="None")

plt.legend()
plt.grid()
plt.show()

# %%
opt = Optimizer([(-2.0, 2.0)])
y_vals = []
x_vals = []
for i in range(30):
    suggested = opt.ask()
    y = f(suggested)
    opt.tell(x=suggested, y=y)
    print('iteration:', i, 'x=',suggested, 'f(x)=', y)
    x_vals.append(suggested)
    y_vals.append(y)
# Out:
# iteration: 0 x= [-1.659902614631413] f(x)= -0.020225276100212252
# iteration: 1 x= [-0.02714262921557431] f(x)= -0.12003569751803887
# iteration: 2 x= [-1.0285986712822017] f(x)= 0.17854132389812305
# iteration: 3 x= [1.6616000072342199] f(x)= -0.065658253143782
# iteration: 4 x= [-1.9476970098681363] f(x)= 0.05510018822610639
# iteration: 5 x= [-0.7482955549263812] f(x)= 0.2694892415841434
# iteration: 6 x= [-0.9061233236395589] f(x)= 0.3092171476503633
# iteration: 7 x= [0.801253771909177] f(x)= -0.3199517048565903
# iteration: 8 x= [1.7212111076346894] f(x)= 0.0041399192759889345
# iteration: 9 x= [0.07893074096215269] f(x)= 0.46561989797389997
# iteration: 10 x= [0.8082437688518538] f(x)= -0.3124483259714284
# iteration: 11 x= [0.7142511662604054] f(x)= -0.18264336916701218
# iteration: 12 x= [-0.12095497814245082] f(x)= -0.5567343644347217
# iteration: 13 x= [-0.18115650940440142] f(x)= -0.8339940781008511
# iteration: 14 x= [-0.30012605600598774] f(x)= -0.8729885052428603
# iteration: 15 x= [-0.23403179055094392] f(x)= -0.8767740455613001
# iteration: 16 x= [-0.2551547365573814] f(x)= -0.9066842143024242
# iteration: 17 x= [-0.25483435606269356] f(x)= -0.7924627349255723
# iteration: 18 x= [1.180854247697929] f(x)= -0.044935151506172104
# iteration: 19 x= [-0.33779056540880914] f(x)= -0.8783199238266669
# iteration: 20 x= [-0.2980744891997835] f(x)= -0.8428373162590603
# iteration: 21 x= [-0.40391183140908504] f(x)= -0.7846669369787836
# iteration: 22 x= [-0.3047246117228193] f(x)= -0.8804926386904057
# iteration: 23 x= [2.0] f(x)= 0.07709847850167141
# iteration: 24 x= [-0.27998598830851407] f(x)= -0.9100889813758736
# iteration: 25 x= [-0.2807916394066525] f(x)= -1.000259892501736
# iteration: 26 x= [-1.3640307644810152] f(x)= -0.01898793774303846
# iteration: 27 x= [-0.28406319122719603] f(x)= -0.9322610718573686
# iteration: 28 x= [1.4236542016823992] f(x)= -0.06485180222327525
# iteration: 29 x= [-0.2846413957739129] f(x)= -0.8972997733693576

# %%
x_vals[np.argmin(y_vals)]
# Out:
# [-0.2807916394066525]

# %%
opt.space
# Out:
# Space([Real(low=-2.0, high=2.0, prior='uniform', transform='normalize')])

# %%
noise_level = 0.05

x = np.linspace(-2, 2, 400).reshape(-1, 1)

fx = [f(x_i, noise_level=noise_level) for x_i in x]
plt.plot(x, fx, "r--", label="True (unknown)")
#plt.plot(x_vals[np.argmin(y_vals)],np.min(y_vals),"b--")

plt.axvline(x=x_vals[np.argmin(y_vals)])  # vertical line min value

plt.fill(np.concatenate([x, x[::-1]]),
         np.concatenate(([fx_i - 1.9600 * noise_level for fx_i in fx], 
                         [fx_i + 1.9600 * noise_level for fx_i in fx[::-1]])),
         alpha=.2, fc="r", ec="None")


plt.legend()
plt.grid()
plt.show()

# %%
opt = Optimizer([(-2.0, 2.0)])
y_vals = []
x_vals = []
for i in range(n_samples):
    suggested = opt.ask()         # get a sparkconf parameter setting
    y = f(suggested)              # run spark job and measure execution time
    opt.tell(suggested, y)        # tell the optimizer the execution time
    print('iteration:', i, 'x=',suggested, 'f(x)=', y)
    x_vals.append(suggested)
    y_vals.append(y)
