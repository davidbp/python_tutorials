# %%
import os
from pathlib import Path
import hashlib
import ipyplot
import numpy as np
from PIL import Image

# %% [markdown]
# ### Step 1: Navigate over fodler and subfolders
#
#
# First lets us see how we can navigate over folders and subfolders

# %%
path = './data'
for dirpath, dirnames, filenames in os.walk(path):
    print('Current path:', dirpath)
    print('Directories:', dirnames)
    print('Files:', filenames)
    print()
# Out:
# Current path: ./data
# Directories: ['f2', '.ipynb_checkpoints', 'f1']
# Files: ['.DS_Store']
#
# Current path: ./data/f2
# Directories: []
# Files: ['1653 copy2.jpg', '1637 copy2.jpg', '1654 copy2.jpg', '2827.jpg', '2828.jpg']
#
# Current path: ./data/.ipynb_checkpoints
# Directories: []
# Files: ['Untitled-checkpoint.ipynb']
#
# Current path: ./data/f1
# Directories: ['f3']
# Files: ['1637.jpg', '1636.jpg', '1806.jpg', '.DS_Store', '1653 copy.jpg', '1654.jpg', '1654 copy.jpg', '1653.jpg', '2211.jpg', '2218.jpg', '1831.jpg', '1637 copy.jpg', '1836.jpg']
#
# Current path: ./data/f1/f3
# Directories: []
# Files: ['1653 copy.jpg', '1654 copy.jpg', '2827.jpg', '2828.jpg']

# %% [markdown]
# ### Step 2: store a dict with file hashes as keys and paths of the files as values
#
#
# We can store as keys file hashes

# %%
path = './data'

file_list = os.walk(path)

file_hashes = dict()
for root,folders,files in file_list:
    for file in files:
        path = Path(os.path.join(root,file))
        fhash = hashlib.md5(open(path,'rb').read()).hexdigest()
        
        if fhash in file_hashes:
            file_hashes[fhash].append(path)
        else:
            file_hashes[fhash] = [path]

# %%
duplicate_file_paths = [x[1] for x in file_hashes.items() if len(x[1])>1]

# %%
duplicate_file_paths
# Out:
# [[PosixPath('data/f2/1653 copy2.jpg'),
#   PosixPath('data/f1/1653 copy.jpg'),
#   PosixPath('data/f1/1653.jpg'),
#   PosixPath('data/f1/f3/1653 copy.jpg')],
#  [PosixPath('data/f2/1637 copy2.jpg'),
#   PosixPath('data/f1/1637.jpg'),
#   PosixPath('data/f1/1637 copy.jpg')],
#  [PosixPath('data/f2/1654 copy2.jpg'),
#   PosixPath('data/f1/1654.jpg'),
#   PosixPath('data/f1/1654 copy.jpg'),
#   PosixPath('data/f1/f3/1654 copy.jpg')],
#  [PosixPath('data/f2/2827.jpg'), PosixPath('data/f1/f3/2827.jpg')],
#  [PosixPath('data/f2/2828.jpg'), PosixPath('data/f1/f3/2828.jpg')]]

# %% [markdown]
# ### Step 3: Show duplicates
#
# Now let us plot the duplicates from `duplicate_file_paths`

# %%
duplicates = [str(x) for x in duplicate_file_paths[1]]
images = [Image.open(f).resize((128,128)) for f in duplicates]

# %%
for duplicates in duplicate_file_paths:
    images = [str(x) for x in duplicates]
    ipyplot.plot_images(images)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-T6Jbk8XuRB8PFuyMU7a5Xf {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-T6Jbk8XuRB8PFuyMU7a5Xf {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-T6Jbk8XuRB8PFuyMU7a5Xf {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-T6Jbk8XuRB8PFuyMU7a5Xf:checked ~ #ipyplot-html-viewer-textarea-T6Jbk8XuRB8PFuyMU7a5Xf {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle
show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-XmNhQPJaxaQLEqXqFPaQQp" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-kuroTErYv5z8ex6iJgpG9X {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kuroTErYv5z8ex6iJgpG9X {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kuroTErYv5z8ex6iJgpG9X">
#     <div class="ipyplot-placeholder-div-kuroTErYv5z8ex6iJgpG9X">
#         <div id="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-WZtgnCsrNu85FV6Kf5YzPo" class="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f2/1637 copy2.jpg</h4><img src="data/f2/1637 copy2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-WZtgnCsrNu85FV6Kf5YzPo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kuroTErYv5z8ex6iJgpG9X">
#         <div id="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-ieASGXTSJJzcGsMwhUr6nK" class="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/1637.jpg</h4><img src="data/f1/1637.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-ieASGXTSJJzcGsMwhUr6nK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kuroTErYv5z8ex6iJgpG9X">
#         <div id="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-JmK6ijccTeM8vw3X9ubQTz" class="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/1637 copy.jpg</h4><img src="data/f1/1637 copy.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-JmK6ijccTeM8vw3X9ubQTz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-kuroTErYv5z8ex6iJgpG9X {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kuroTErYv5z8ex6iJgpG9X {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kuroTErYv5z8ex6iJgpG9X">
#     <div class="ipyplot-placeholder-div-kuroTErYv5z8ex6iJgpG9X">
#         <div id="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-WZtgnCsrNu85FV6Kf5YzPo" class="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f2/1637 copy2.jpg</h4><img src="data/f2/1637 copy2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-WZtgnCsrNu85FV6Kf5YzPo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kuroTErYv5z8ex6iJgpG9X">
#         <div id="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-ieASGXTSJJzcGsMwhUr6nK" class="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/1637.jpg</h4><img src="data/f1/1637.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-ieASGXTSJJzcGsMwhUr6nK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kuroTErYv5z8ex6iJgpG9X">
#         <div id="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-JmK6ijccTeM8vw3X9ubQTz" class="ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/1637 copy.jpg</h4><img src="data/f1/1637 copy.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kuroTErYv5z8ex6iJgpG9X-JmK6ijccTeM8vw3X9ubQTz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-E573obdcc8dK4UQKcHo2qL {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-E573obdcc8dK4UQKcHo2qL {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-E573obdcc8dK4UQKcHo2qL {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-E573obdcc8dK4UQKcHo2qL:checked ~ #ipyplot-html-viewer-textarea-E573obdcc8dK4UQKcHo2qL {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-E573obdcc8dK4UQKcHo2qL:checked + #ipyplot-html-viewer-label-E573obdcc8dK4UQKcHo2qL:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-E573obdcc8dK4UQKcHo2qL">
#         <label id="ipyplot-html-viewer-label-E573obdcc8dK4UQKcHo2qL" for="ipyplot-html-viewer-toggle-E573obdcc8dK4UQKcHo2qL">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-E573obdcc8dK4UQKcHo2qL" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-bRRSigvdtBmhMKJweqGzGB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bRRSigvdtBmhMKJweqGzGB {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bRRSigvdtBmhMKJweqGzGB">
#     <div class="ipyplot-placeholder-div-bRRSigvdtBmhMKJweqGzGB">
#         <div id="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-aF2U6ZrsdXUuLzarbf4WL7" class="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f2/1654 copy2.jpg</h4><img src="data/f2/1654 copy2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-aF2U6ZrsdXUuLzarbf4WL7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bRRSigvdtBmhMKJweqGzGB">
#         <div id="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-6UY4LmzQpBCAjzeLeLa7gt" class="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/1654.jpg</h4><img src="data/f1/1654.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-6UY4LmzQpBCAjzeLeLa7gt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bRRSigvdtBmhMKJweqGzGB">
#         <div id="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-Q6PbHi8SMG7uyBhQtHp2kh" class="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/1654 copy.jpg</h4><img src="data/f1/1654 copy.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-Q6PbHi8SMG7uyBhQtHp2kh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bRRSigvdtBmhMKJweqGzGB">
#         <div id="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-3s6w3JzKrJHsgvceS4LdSA" class="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/f3/1654 copy.jpg</h4><img src="data/f1/f3/1654 copy.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-3s6w3JzKrJHsgvceS4LdSA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-bRRSigvdtBmhMKJweqGzGB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bRRSigvdtBmhMKJweqGzGB {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bRRSigvdtBmhMKJweqGzGB">
#     <div class="ipyplot-placeholder-div-bRRSigvdtBmhMKJweqGzGB">
#         <div id="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-aF2U6ZrsdXUuLzarbf4WL7" class="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f2/1654 copy2.jpg</h4><img src="data/f2/1654 copy2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-aF2U6ZrsdXUuLzarbf4WL7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bRRSigvdtBmhMKJweqGzGB">
#         <div id="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-6UY4LmzQpBCAjzeLeLa7gt" class="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/1654.jpg</h4><img src="data/f1/1654.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-6UY4LmzQpBCAjzeLeLa7gt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bRRSigvdtBmhMKJweqGzGB">
#         <div id="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-Q6PbHi8SMG7uyBhQtHp2kh" class="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/1654 copy.jpg</h4><img src="data/f1/1654 copy.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-Q6PbHi8SMG7uyBhQtHp2kh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bRRSigvdtBmhMKJweqGzGB">
#         <div id="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-3s6w3JzKrJHsgvceS4LdSA" class="ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/f3/1654 copy.jpg</h4><img src="data/f1/f3/1654 copy.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bRRSigvdtBmhMKJweqGzGB-3s6w3JzKrJHsgvceS4LdSA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-MZqVLJ2LH5Q98qED23e6yt {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MZqVLJ2LH5Q98qED23e6yt {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MZqVLJ2LH5Q98qED23e6yt {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MZqVLJ2LH5Q98qED23e6yt:checked ~ #ipyplot-html-viewer-textarea-MZqVLJ2LH5Q98qED23e6yt {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MZqVLJ2LH5Q98qED23e6yt:checked + #ipyplot-html-viewer-label-MZqVLJ2LH5Q98qED23e6yt:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-MZqVLJ2LH5Q98qED23e6yt">
#         <label id="ipyplot-html-viewer-label-MZqVLJ2LH5Q98qED23e6yt" for="ipyplot-html-viewer-toggle-MZqVLJ2LH5Q98qED23e6yt">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-MZqVLJ2LH5Q98qED23e6yt" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-2SHviW9xU2E8dJ7ry2edsG {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-2SHviW9xU2E8dJ7ry2edsG {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-2SHviW9xU2E8dJ7ry2edsG">
#     <div class="ipyplot-placeholder-div-2SHviW9xU2E8dJ7ry2edsG">
#         <div id="ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG-FKqTjf8JiP8s7geeXWzzDA" class="ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f2/2827.jpg</h4><img src="data/f2/2827.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG-FKqTjf8JiP8s7geeXWzzDA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2SHviW9xU2E8dJ7ry2edsG">
#         <div id="ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG-LHqCt4nt4KefLddx2CPdSw" class="ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/f3/2827.jpg</h4><img src="data/f1/f3/2827.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG-LHqCt4nt4KefLddx2CPdSw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-2SHviW9xU2E8dJ7ry2edsG {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-2SHviW9xU2E8dJ7ry2edsG {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-2SHviW9xU2E8dJ7ry2edsG">
#     <div class="ipyplot-placeholder-div-2SHviW9xU2E8dJ7ry2edsG">
#         <div id="ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG-FKqTjf8JiP8s7geeXWzzDA" class="ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f2/2827.jpg</h4><img src="data/f2/2827.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG-FKqTjf8JiP8s7geeXWzzDA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2SHviW9xU2E8dJ7ry2edsG">
#         <div id="ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG-LHqCt4nt4KefLddx2CPdSw" class="ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/f3/2827.jpg</h4><img src="data/f1/f3/2827.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2SHviW9xU2E8dJ7ry2edsG-LHqCt4nt4KefLddx2CPdSw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-QVd4gEnx4aK2SsZFGmxabR {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-QVd4gEnx4aK2SsZFGmxabR {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-QVd4gEnx4aK2SsZFGmxabR {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-QVd4gEnx4aK2SsZFGmxabR:checked ~ #ipyplot-html-viewer-textarea-QVd4gEnx4aK2SsZFGmxabR {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-QVd4gEnx4aK2SsZFGmxabR:checked + #ipyplot-html-viewer-label-QVd4gEnx4aK2SsZFGmxabR:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-QVd4gEnx4aK2SsZFGmxabR">
#         <label id="ipyplot-html-viewer-label-QVd4gEnx4aK2SsZFGmxabR" for="ipyplot-html-viewer-toggle-QVd4gEnx4aK2SsZFGmxabR">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-QVd4gEnx4aK2SsZFGmxabR" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-Av4x2fUHryLStNJpRipyNi {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Av4x2fUHryLStNJpRipyNi {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Av4x2fUHryLStNJpRipyNi]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Av4x2fUHryLStNJpRipyNi]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Av4x2fUHryLStNJpRipyNi]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Av4x2fUHryLStNJpRipyNi">
#     <div class="ipyplot-placeholder-div-Av4x2fUHryLStNJpRipyNi">
#         <div id="ipyplot-content-div-Av4x2fUHryLStNJpRipyNi-i9LnVyVfhZNwQStCdphVKm" class="ipyplot-content-div-Av4x2fUHryLStNJpRipyNi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f2/2828.jpg</h4><img src="data/f2/2828.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Av4x2fUHryLStNJpRipyNi-i9LnVyVfhZNwQStCdphVKm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Av4x2fUHryLStNJpRipyNi">
#         <div id="ipyplot-content-div-Av4x2fUHryLStNJpRipyNi-cixyJbRTDYRebPrP5QgLNn" class="ipyplot-content-div-Av4x2fUHryLStNJpRipyNi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/f3/2828.jpg</h4><img src="data/f1/f3/2828.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Av4x2fUHryLStNJpRipyNi-cixyJbRTDYRebPrP5QgLNn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-Av4x2fUHryLStNJpRipyNi {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Av4x2fUHryLStNJpRipyNi {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Av4x2fUHryLStNJpRipyNi span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Av4x2fUHryLStNJpRipyNi]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Av4x2fUHryLStNJpRipyNi]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Av4x2fUHryLStNJpRipyNi]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Av4x2fUHryLStNJpRipyNi">
#     <div class="ipyplot-placeholder-div-Av4x2fUHryLStNJpRipyNi">
#         <div id="ipyplot-content-div-Av4x2fUHryLStNJpRipyNi-i9LnVyVfhZNwQStCdphVKm" class="ipyplot-content-div-Av4x2fUHryLStNJpRipyNi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f2/2828.jpg</h4><img src="data/f2/2828.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Av4x2fUHryLStNJpRipyNi-i9LnVyVfhZNwQStCdphVKm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Av4x2fUHryLStNJpRipyNi">
#         <div id="ipyplot-content-div-Av4x2fUHryLStNJpRipyNi-cixyJbRTDYRebPrP5QgLNn" class="ipyplot-content-div-Av4x2fUHryLStNJpRipyNi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">data/f1/f3/2828.jpg</h4><img src="data/f1/f3/2828.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Av4x2fUHryLStNJpRipyNi-cixyJbRTDYRebPrP5QgLNn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### Step 4: For each of the ducplicate images, remove all but one
#
# We will keep the repeated image with shortest filename among the repeated names. This should keep "image.jpgeg" from "image_copy.jpeg" or "image2.jpeg".

# %%
get_len = lambda x: len(x.stem)
duplicates = duplicate_file_paths[0]
keep_index = np.argmin(list(map(get_len, duplicates)))

# %%
for duplicates in duplicate_file_paths:
    keep_index = np.argmin(list(map(get_len, duplicates)))
    for i, duplicate in enumerate(duplicates):
        if keep_index != i:
            print(f"removed file {duplicate}")
            os.remove(duplicate)
# Out:
# removed file data/f2/1653 copy2.jpg
# removed file data/f1/1653 copy.jpg
# removed file data/f1/f3/1653 copy.jpg
# removed file data/f2/1637 copy2.jpg
# removed file data/f1/1637 copy.jpg
# removed file data/f2/1654 copy2.jpg
# removed file data/f1/1654 copy.jpg
# removed file data/f1/f3/1654 copy.jpg
# removed file data/f1/f3/2827.jpg
# removed file data/f1/f3/2828.jpg
